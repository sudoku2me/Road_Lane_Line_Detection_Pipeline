# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

image_in = mpimg.imread('Transformation6.jpg')
image_in2 = mpimg.imread('solidYellowCurve.jpg')
initial_image = image_in2.astype('uint8')
image_in = image_in.astype('uint8')
old_image_height, old_image_width, channels = initial_image.shape
image_in_height, image_in_width, channels = image_in.shape
#print(initial_image.shape)
# print(image_in.shape)
dimension=(old_image_width,old_image_height)
# image_in = cv2.copyMakeBorder(image_in, old_image_height-image_in_height, 0, 0, old_image_width-image_in_width, cv2.BORDER_CONSTANT, None, value = 0)
image_in = cv2.resize(image_in,dimension)
print(image_in.shape)
annotated_image = weighted_img(image_in, initial_image)
plt.imshow(annotated_image)
plt.axis('off')
transformation = plt.imshow
plt.savefig('Final_Image.jpg',bbox_inches='tight',transparent=True, pad_inches=0)
# Out:
# (540, 960, 3)
